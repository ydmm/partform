# %% [markdown]
# # Transmittograms
# This notebook describes a simple example of how a transmittogram can be generated.

# %%
from src.AC import *

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## Silica nanoparticle dispersion

# %%
# load data
silica500 = 'data/silica_500nm_0.4%.xlsx' 
si500 = AC(path=silica500, sheet_num=0)
si500.__eval__()
# Out:
# Silica 500 nm 0.40 %   |  Silica 500 nm 0.40 % m/m 20200212 14:14:04
# ---------------------------------------------------------------
# Data recorded on 2020-12-02 14:14:04
# 256 profiles acquired at an interval of 10.0 secs each
# Temperature of experiment was 25.0 degrees
# Speed of experiment was 1993.0 RPM
# Experiment started at 14:14:05 and stopped at 14:56:35

# %%
si500.plot_profiles()

# %%
si500.plot_transmittogram()

# %% [markdown]
# ## Silica nanoparticle bimodal dispersion

# %%
silica500_750 = 'data/silica_500_750.xlsx' #sheet3
si500_750 = AC(path=silica500_750, sheet_num=0)
si500_750.__eval__()
# Out:
# Silica 500_750 nm 0.40_sample1  |  Silica 500_750 nm 0.40 % m/m 20200214 14:20:32
# ---------------------------------------------------------------
# Data recorded on 2/14/2020 2:20:32 PM
# 256 profiles acquired at an interval of 10.0 secs each
# Temperature of experiment was 25.0 degrees
# Speed of experiment was 1992.0 RPM
# Experiment started at 14:20:33 and stopped at 15:03:02

# %%
si500_750.plot_profiles()

# %%
si500_750.plot_transmittogram()
